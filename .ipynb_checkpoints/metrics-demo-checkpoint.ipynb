# %% [markdown]
# Install the prometheus packages

# %%
pip install prometheus-api-client
# Out:
# Requirement already satisfied: prometheus-api-client in /opt/app-root/lib/python3.9/site-packages (0.5.5)
# Requirement already satisfied: requests in /opt/app-root/lib/python3.9/site-packages (from prometheus-api-client) (2.31.0)
# Requirement already satisfied: httmock in /opt/app-root/lib/python3.9/site-packages (from prometheus-api-client) (1.4.0)
# Requirement already satisfied: numpy in /opt/app-root/lib/python3.9/site-packages (from prometheus-api-client) (1.24.4)
# Requirement already satisfied: matplotlib in /opt/app-root/lib/python3.9/site-packages (from prometheus-api-client) (3.6.3)
# Requirement already satisfied: pandas>=1.4.0 in /opt/app-root/lib/python3.9/site-packages (from prometheus-api-client) (1.5.3)
# Requirement already satisfied: dateparser in /opt/app-root/lib/python3.9/site-packages (from prometheus-api-client) (1.2.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/app-root/lib/python3.9/site-packages (from pandas>=1.4.0->prometheus-api-client) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/app-root/lib/python3.9/site-packages (from pandas>=1.4.0->prometheus-api-client) (2.8.2)
# Requirement already satisfied: tzlocal in /opt/app-root/lib/python3.9/site-packages (from dateparser->prometheus-api-client) (5.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /opt/app-root/lib/python3.9/site-packages (from dateparser->prometheus-api-client) (2023.12.25)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/app-root/lib/python3.9/site-packages (from requests->prometheus-api-client) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/app-root/lib/python3.9/site-packages (from requests->prometheus-api-client) (1.26.18)
# Requirement already satisfied: idna<4,>=2.5 in /opt/app-root/lib/python3.9/site-packages (from requests->prometheus-api-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/app-root/lib/python3.9/site-packages (from requests->prometheus-api-client) (2023.7.22)
# Requirement already satisfied: pillow>=6.2.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib->prometheus-api-client) (10.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib->prometheus-api-client) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib->prometheus-api-client) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib->prometheus-api-client) (4.44.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/app-root/lib/python3.9/site-packages (from matplotlib->prometheus-api-client) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/app-root/lib/python3.9/site-packages (from matplotlib->prometheus-api-client) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /opt/app-root/lib/python3.9/site-packages (from matplotlib->prometheus-api-client) (23.2)
# Requirement already satisfied: six>=1.5 in /opt/app-root/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.4.0->prometheus-api-client) (1.16.0)
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from torch.utils.data import Dataset, DataLoader

import torch
import torch.nn as nn

from prometheus_api_client import PrometheusConnect, MetricsList, MetricSnapshotDataFrame
from prometheus_api_client.utils import parse_datetime

from datetime import datetime, timedelta

# %% [markdown]
# Create a data connection to prometheus instance

# %%
# prometheus from which metrics are to be fetched
PROM_URL = "https://thanos-querier.openshift-monitoring.svc.cluster.local:9091"
PROM_ACCESS_TOKEN = "eyJhbGciOiJSUzI1NiIsImtpZCI6IjZ1UlNpRTVFM3E0ZkJYYWhKb0swdUpBMmZHNE5aRDdnN0ExWFdGRzNWNmcifQ.....KQ1xwk8sjjtURhCl9Fp0S9U10-2dZgQlMU9KOlg7Na2WeGGyIORFD58OGo2pqs7QvKRwLnw-gvhuO6fP4c44a6O-1x81BSS2M5bgsfKoj0nwmlGBHJIfNMR5JSFhQjbBfBJnM5DJ793aCjdVejsh8u_fThbAWSfZY-2su-nrZs1fipaGodMIrLcqPp5lRy5F4KwB83WNMgcRX6Pim4IYcasDWR4Rx9VNE1EmPTg6tbGM9TtD4BXehUogCZmjKZ3WYGQhsqrrPsMAW_R1u_FZxDwaeoZO9G-suro6pNZkjewHJEP0oJM7L9LWlwJ7xzA7_z_Y6y_FEPgKHHp3jmrX-ARFBpondMSTlCVahhpv5bJFmOj-AeXvrrAwzft58gDxHBJEu_UJwHosrXvSkKPydy7waypPMIT2_uxeadZS0McKn9hO2fisNzk7zdvzxgMhgOmwFoZobK8589_c_AjqmF2YTjkfVpcgdoNpWGC0bAaDQi5Pe6tUjy_sHsFJPNvMtLhSO6Flp-2hQ0LtXfX6llI-DVpkxvU6UvMLQTmPQPjJpUGJTa0yy1PYUwoeHJ3GEGdkcQKoEvrUmp9MH2enbnwjipD-blGmiIbnnPp6-dKXJABtFkEl5a-r-lJ3wxs63anoBPK6RRg6ZlqF1O5YM48-N-lEtoMO_AyKXFxlCa4"

# prom connector does the "talking to prometheus" part of the nb, facilitates
# data (prometheus metrics) fetching
prom = PrometheusConnect(
    url=PROM_URL,
    disable_ssl=True,
    headers={"Authorization": f"bearer {PROM_ACCESS_TOKEN}"},
)

# %% [markdown]
# Query data

# %%
# Here, we are fetching the values of a particular metric name
#prom.custom_query(query="pod:container_cpu_usage:sum{namespace=\"ic-shared-llm\", pod=\"llm-55cb7cd7f-x6848\", prometheus=\"openshift-monitoring/k8s\"}[15s]")
start_time = parse_datetime("2d") 
end_time = parse_datetime("now") 
chunk_size = timedelta(hours=1) 
my_label_config = {'prometheus': 'openshift-monitoring/k8s', 'namespace': 'ic-shared-llm', 'pod': 'llm-55cb7cd7f-x6848'}
metric_data = prom.get_metric_range_data(metric_name='pod:container_cpu_usage:sum', 
                                         label_config=my_label_config,
                                        start_time=start_time, 
                                         end_time=end_time, 
                                         chunk_size=chunk_size)
metric_df = MetricSnapshotDataFrame(metric_data)
metric_df
#metric_list = MetricsList(metric_data)

#for metric in metric_list:
#    print(metric)
# Out:
#                        __name__      namespace                  pod  \
# 0   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 1   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 2   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 3   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 4   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 5   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 6   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 7   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 8   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 9   pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 10  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 11  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 12  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 13  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 14  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 15  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 16  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 17  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 18  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 19  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 20  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 21  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 22  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 23  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 24  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 25  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 26  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 27  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 28  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 29  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
# 30  pod:container_cpu_usage:sum  ic-shared-llm  llm-55cb7cd7f-x6848
#
#                   prometheus                     timestamp     value
# 0   openshift-monitoring/k8s 2024-03-07 04:18:04.546000128  0.052145
# 1   openshift-monitoring/k8s 2024-03-07 05:18:04.546000128  0.000649
# 2   openshift-monitoring/k8s 2024-03-07 06:18:04.546000128  0.000638
# 3   openshift-monitoring/k8s 2024-03-07 07:18:04.546000128  0.000643
# 4   openshift-monitoring/k8s 2024-03-07 08:18:04.546000128  0.000641
# 5   openshift-monitoring/k8s 2024-03-07 09:18:04.546000128  0.000613
# 6   openshift-monitoring/k8s 2024-03-07 10:18:04.546000128  0.000660
# 7   openshift-monitoring/k8s 2024-03-07 11:18:04.546000128  0.000642
# 8   openshift-monitoring/k8s 2024-03-07 12:18:04.546000128  0.000635
# 9   openshift-monitoring/k8s 2024-03-07 13:18:04.546000128  0.000643
# 10  openshift-monitoring/k8s 2024-03-07 14:18:04.546000128  0.000654
# 11  openshift-monitoring/k8s 2024-03-07 15:18:04.546000128  0.000647
# 12  openshift-monitoring/k8s 2024-03-07 16:18:04.546000128  0.000633
# 13  openshift-monitoring/k8s 2024-03-07 17:18:04.546000128  0.000652
# 14  openshift-monitoring/k8s 2024-03-07 18:18:04.546000128  0.000630
# 15  openshift-monitoring/k8s 2024-03-07 19:18:04.546000128  0.000626
# 16  openshift-monitoring/k8s 2024-03-07 20:18:04.546000128  0.000655
# 17  openshift-monitoring/k8s 2024-03-07 21:18:04.546000128  0.000626
# 18  openshift-monitoring/k8s 2024-03-07 22:18:04.546000128  0.000637
# 19  openshift-monitoring/k8s 2024-03-07 23:18:04.546000128  0.000601
# 20  openshift-monitoring/k8s 2024-03-08 00:18:04.546000128  0.000634
# 21  openshift-monitoring/k8s 2024-03-08 01:18:04.546000128  0.000596
#        [0.00063703, 0.00062575, 0.00065471, 0.00062606, 0.00063025,
#         0.00065247, 0.00063253, 0.0006469 ],
#        [0.00060124, 0.00063703, 0.00062575, 0.00065471, 0.00062606,
#         0.00063025, 0.00065247, 0.00063253],
#        [0.00063443, 0.00060124, 0.00063703, 0.00062575, 0.00065471,
#         0.00062606, 0.00063025, 0.00065247],
#        [0.00059649, 0.00063443, 0.00060124, 0.00063703, 0.00062575,
#         0.00065471, 0.00062606, 0.00063025],
#        [0.00062715, 0.00059649, 0.00063443, 0.00060124, 0.00063703,
#         0.00062575, 0.00065471, 0.00062606],
#        [0.00061191, 0.00062715, 0.00059649, 0.00063443, 0.00060124,
#         0.00063703, 0.00062575, 0.00065471],
#        [0.00063293, 0.00061191, 0.00062715, 0.00059649, 0.00063443,
#         0.00060124, 0.00063703, 0.00062575],
#        [0.00061168, 0.00063293, 0.00061191, 0.00062715, 0.00059649,
#         0.00063443, 0.00060124, 0.00063703],
#        [0.00063317, 0.00061168, 0.00063293, 0.00061191, 0.00062715,
#         0.00059649, 0.00063443, 0.00060124],
#        [0.00060547, 0.00063317, 0.00061168, 0.00063293, 0.00061191,
#         0.00062715, 0.00059649, 0.00063443],
#        [0.0006368 , 0.00060547, 0.00063317, 0.00061168, 0.00063293,
#         0.00061191, 0.00062715, 0.00059649],
#        [0.00060883, 0.0006368 , 0.00060547, 0.00063317, 0.00061168,
#         0.00063293, 0.00061191, 0.00062715],
#        [0.00061629, 0.00060883, 0.0006368 , 0.00060547, 0.00063317,
#         0.00061168, 0.00063293, 0.00061191]])

# %% [markdown]
# Let's look at the shape now

# %%
shifted_df_as_np.shape
np.save('data', shifted_df_as_np)
shifted_df_as_np = np.load("data.npy")

# %%
scaler = MinMaxScaler(feature_range=(-1, 1))
shifted_df_as_np = scaler.fit_transform(shifted_df_as_np)

X = shifted_df_as_np[:, 1:]
y = shifted_df_as_np[:, 0]
X = dc(np.flip(X, axis=1))

# %% [markdown]
# Split data into training and validate

# %%
split_index = int(len(X) * 0.95)
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train = X_train.reshape((-1, lookback, 1))
X_test = X_test.reshape((-1, lookback, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([22, 7, 1]),
#  torch.Size([2, 7, 1]),
#  torch.Size([22, 1]),
#  torch.Size([2, 1]))

# %% [markdown]
# Create the data structure

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]
    
train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %% [markdown]
# Model

# %%
batch_size = 30

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to("cpu"), batch[1].to("cpu")
    print(x_batch.shape, y_batch.shape)
    break
    
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_stacked_layers):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_stacked_layers = num_stacked_layers

        self.lstm = nn.LSTM(input_size, hidden_size, num_stacked_layers, 
                            batch_first=True)
        
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        batch_size = x.size(0)
        h0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to("cpu")
        c0 = torch.zeros(self.num_stacked_layers, batch_size, self.hidden_size).to("cpu")
        
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])
        return out
    
model = LSTM(1, 4, 1)
model.to("cpu")

def train_one_epoch():
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0

    for batch_index, batch in enumerate(train_loader):
        x_batch, y_batch = batch[0].to("cpu"), batch[1].to("cpu")

        output = model(x_batch)
        loss = loss_function(output, y_batch)
        running_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch_index % 100 == 99:  # print every 100 batches
            avg_loss_across_batches = running_loss / 100
            print('Batch {0}, Loss: {1:.3f}'.format(batch_index+1,
                                                    avg_loss_across_batches))
            running_loss = 0.0
    print()

def validate_one_epoch():
    model.train(False)
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to("cpu"), batch[1].to("cpu")

        with torch.no_grad():
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()

    avg_loss_across_batches = running_loss / len(test_loader)

    print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
    print('***************************************************')
    print()
# Out:
# torch.Size([10, 7, 1]) torch.Size([10, 1])

# %% [markdown]
# Build the model

# %%
learning_rate = 0.01
num_epochs = 10
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_one_epoch()
    validate_one_epoch()
# Out:
# Epoch: 1
#
# Val Loss: 0.195
# ***************************************************
#
# Epoch: 2
#
# Val Loss: 0.223
# ***************************************************
#
# Epoch: 3
#
# Val Loss: 0.257
# ***************************************************
#
# Epoch: 4
#
# Val Loss: 0.299
# ***************************************************
#
# Epoch: 5
#
# Val Loss: 0.331
# ***************************************************
#
# Epoch: 6
#
# Val Loss: 0.371
# ***************************************************
#
# Epoch: 7
#
# Val Loss: 0.412
# ***************************************************
#
# Epoch: 8
#
# Val Loss: 0.453
# ***************************************************
#
# Epoch: 9
#
# Val Loss: 0.478
# ***************************************************
#
# Epoch: 10
#
# Val Loss: 0.461
# ***************************************************
#
# Epoch: 11
#
# Val Loss: 0.444
# ***************************************************
#
# Epoch: 12
#
# Val Loss: 0.415
# ***************************************************
#
# Epoch: 13
#
# Val Loss: 0.361
# ***************************************************
#
# Epoch: 14
#
# Val Loss: 0.289
# ***************************************************
#
# Epoch: 15
#
# Val Loss: 0.238
# ***************************************************
#
# Epoch: 16
#
# Val Loss: 0.201
# ***************************************************
#
# Epoch: 17
#
# Val Loss: 0.165
# ***************************************************
#
# Epoch: 18
#
# Val Loss: 0.145
# ***************************************************
#
# Epoch: 19
#
# Val Loss: 0.130
# ***************************************************
#
# Epoch: 20
#
# Val Loss: 0.126
# ***************************************************
#
# Epoch: 21
#
# Val Loss: 0.145
# ***************************************************
#
# Epoch: 22
#
# Val Loss: 0.170
# ***************************************************
#
# Epoch: 23
#
# Val Loss: 0.186
# ***************************************************
#
# Epoch: 24
#
# Val Loss: 0.197
# ***************************************************
#
# Epoch: 25
#
# Val Loss: 0.186
# ***************************************************
#
# Epoch: 26
#
# Val Loss: 0.167
# ***************************************************
#
# Epoch: 27
#
# Val Loss: 0.142
# ***************************************************
#
# Epoch: 28
#
# Val Loss: 0.123
# ***************************************************
#
# Epoch: 29
#
# Val Loss: 0.110
# ***************************************************
#
# Epoch: 30
#
# Val Loss: 0.105
# ***************************************************
#
# Epoch: 31
#
# Val Loss: 0.093
# ***************************************************
#
# Epoch: 32
#
# Val Loss: 0.090
# ***************************************************
#
# Epoch: 33
#
# Val Loss: 0.089
# ***************************************************
#
# Epoch: 34
#
# Val Loss: 0.093
# ***************************************************
#
# Epoch: 35
#
# Val Loss: 0.096
# ***************************************************
#
# Epoch: 36
#
# Val Loss: 0.095
# ***************************************************
#
# Epoch: 37
#
# Val Loss: 0.097
# ***************************************************
#
# Epoch: 38
#
# Val Loss: 0.101
# ***************************************************
#
# Epoch: 39
#
# Val Loss: 0.101
# ***************************************************
#
# Epoch: 40
#
# Val Loss: 0.101
# ***************************************************
#
# Epoch: 41
#
# Val Loss: 0.103
# ***************************************************
#
# Epoch: 42
#
# Val Loss: 0.108
# ***************************************************
#
# Epoch: 43
#
# Val Loss: 0.118
# ***************************************************
#
# Epoch: 44
#
# Val Loss: 0.129
# ***************************************************
#
# Epoch: 45
#
# Val Loss: 0.144
# ***************************************************
#
# Epoch: 46
#
# Val Loss: 0.153
# ***************************************************
#
# Epoch: 47
#
# Val Loss: 0.163
# ***************************************************
#
# Epoch: 48
#
# Val Loss: 0.174
# ***************************************************
#
# Epoch: 49
#
# Val Loss: 0.177
# ***************************************************
#
# Epoch: 50
#
# Val Loss: 0.176
# ***************************************************
#
# Epoch: 51
#
# Val Loss: 0.175
# ***************************************************
#
# Epoch: 52
#
# Val Loss: 0.173
# ***************************************************
#
# Epoch: 53
#
# Val Loss: 0.172
# ***************************************************
#
# Epoch: 54
#
# Val Loss: 0.170
# ***************************************************
#
# Epoch: 55
#
# Val Loss: 0.169
# ***************************************************
#
# Epoch: 56
#
# Val Loss: 0.176
# ***************************************************
#
# Epoch: 57
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 58
#
# Val Loss: 0.193
# ***************************************************
#
# Epoch: 59
#
# Val Loss: 0.205
# ***************************************************
#
# Epoch: 60
#
# Val Loss: 0.216
# ***************************************************
#
# Epoch: 61
#
# Val Loss: 0.221
# ***************************************************
#
# Epoch: 62
#
# Val Loss: 0.216
# ***************************************************
#
# Epoch: 63
#
# Val Loss: 0.207
# ***************************************************
#
# Epoch: 64
#
# Val Loss: 0.191
# ***************************************************
#
# Epoch: 65
#
# Val Loss: 0.184
# ***************************************************
#
# Epoch: 66
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 67
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 68
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 69
#
# Val Loss: 0.187
# ***************************************************
#
# Epoch: 70
#
# Val Loss: 0.196
# ***************************************************
#
# Epoch: 71
#
# Val Loss: 0.202
# ***************************************************
#
# Epoch: 72
#
# Val Loss: 0.204
# ***************************************************
#
# Epoch: 73
#
# Val Loss: 0.204
# ***************************************************
#
# Epoch: 74
#
# Val Loss: 0.202
# ***************************************************
#
# Epoch: 75
#
# Val Loss: 0.196
# ***************************************************
#
# Epoch: 76
#
# Val Loss: 0.187
# ***************************************************
#
# Epoch: 77
#
# Val Loss: 0.182
# ***************************************************
#
# Epoch: 78
#
# Val Loss: 0.179
# ***************************************************
#
# Epoch: 79
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 80
#
# Val Loss: 0.187
# ***************************************************
#
# Epoch: 81
#
# Val Loss: 0.190
# ***************************************************
#
# Epoch: 82
#
# Val Loss: 0.194
# ***************************************************
#
# Epoch: 83
#
# Val Loss: 0.201
# ***************************************************
#
# Epoch: 84
#
# Val Loss: 0.211
# ***************************************************
#
# Epoch: 85
#
# Val Loss: 0.218
# ***************************************************
#
# Epoch: 86
#
# Val Loss: 0.217
# ***************************************************
#
# Epoch: 87
#
# Val Loss: 0.210
# ***************************************************
#
# Epoch: 88
#
# Val Loss: 0.203
# ***************************************************
#
# Epoch: 89
#
# Val Loss: 0.195
# ***************************************************
#
# Epoch: 90
#
# Val Loss: 0.186
# ***************************************************
#
# Epoch: 91
#
# Val Loss: 0.179
# ***************************************************
#
# Epoch: 92
#
# Val Loss: 0.181
# ***************************************************
#
# Epoch: 93
#
# Val Loss: 0.183
# ***************************************************
#
# Epoch: 94
#
# Val Loss: 0.193
# ***************************************************
#
# Epoch: 95
#
# Val Loss: 0.206
# ***************************************************
#
# Epoch: 96
#
# Val Loss: 0.213
# ***************************************************
#
# Epoch: 97
#
# Val Loss: 0.216
# ***************************************************
#
# Epoch: 98
#
# Val Loss: 0.215
# ***************************************************
#
# Epoch: 99
#
# Val Loss: 0.215
# ***************************************************
#
# Epoch: 100
#
# Val Loss: 0.214
# ***************************************************

# %% [markdown]
# Plot the model

# %%
with torch.no_grad():
    predicted = model(X_train.to("cpu")).to('cpu').numpy()

plt.plot(y_train, label='Actual Value')
plt.plot(predicted, label='Predicted Value')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
train_predictions = predicted.flatten()

dummies = np.zeros((X_train.shape[0], lookback+1))
dummies[:, 0] = train_predictions
dummies = scaler.inverse_transform(dummies)

train_predictions = dc(dummies[:, 0])

dummies = np.zeros((X_train.shape[0], lookback+1))
dummies[:, 0] = y_train.flatten()
dummies = scaler.inverse_transform(dummies)

new_y_train = dc(dummies[:, 0])

# %%
plt.plot(new_y_train, label='Actual Value')
plt.plot(train_predictions, label='Predicted Value')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
test_predictions = model(X_test.to("cpu")).detach().cpu().numpy().flatten()

dummies = np.zeros((X_test.shape[0], lookback+1))
dummies[:, 0] = test_predictions
dummies = scaler.inverse_transform(dummies)

test_predictions = dc(dummies[:, 0])
test_predictions
# Out:
# array([0.00060108, 0.0006337 ])

# %%
dummies = np.zeros((X_test.shape[0], lookback+1))
dummies[:, 0] = y_test.flatten()
dummies = scaler.inverse_transform(dummies)

new_y_test = dc(dummies[:, 0])
new_y_test
# Out:
# array([0.00060883, 0.00061629])

# %%
plt.plot(new_y_test, label='Actual Value')
plt.plot(test_predictions, label='Predicted Value')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), "metrics-model.pt")
